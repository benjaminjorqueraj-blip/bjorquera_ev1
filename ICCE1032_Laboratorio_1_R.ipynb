# %% [markdown]
# # 🔬🧪🥼 Laboratorio 1: Primeras nociones de Programación Orientada a Objetos
# ## Contexto: Sistema básico de salas
#
# **Duración sugerida:** 2 hora 20 minutos
# **Modalidad:** trabajo guiado en Google Colab, con respaldo en GitHub
#
# ## 🎯 Objetivo
# Comprender las primeras nociones de programación orientada a objetos mediante la abstracción de un contexto cercano, identificando clases, objetos, atributos, métodos e interfaz básica, y construyendo una primera estructura simple en Python.

# %% [markdown]
# **Instrucciones de entrega:** El laboratorio debe ser desarrollado y entregado en un archivo `.ipynb`, alojado en el repositorio personal de GitHub de cada estudiante.
#
# Las preguntas de reflexión o análisis deben responderse en **celdas de texto (Markdown)**, mientras que toda implementación, prueba y programación debe realizarse en **celdas de código**.

# %% [markdown]
# ## 🤔 1. Antes de programar: pensar el problema
#
# Una institución desea representar sus salas en un sistema simple. Cada sala tiene información relevante, por ejemplo:
#
# - nombre o código
# - capacidad
# - ubicación
# - disponibilidad
# - tipo de sala
#
# Además, se espera que el sistema pueda realizar algunas acciones simples, por ejemplo:
#
# - mostrar la información de la sala
# - reservar la sala
# - liberar la sala
#
# ### Responde con tus palabras
# 1. ¿Qué es una sala dentro de este sistema?
# 2. ¿Qué características son importantes para representarla?
# 3. ¿Qué acciones debería poder realizar?
# 4. ¿Qué detalles del mundo real no son necesarios todavía?

# %% [markdown]
# 1. una sala es un espacio fisico de la universidad que se puede reservar para usarla, ya sea para clases, laboratorio o lo que sea
#
# 2. lo mas importante seria el nombre para identificarla, cuanta gente cabe, donde esta ubicada y si esta disponible o no
#
# 3. deberia poder mostrar su info, reservarse y liberarse
#
# 4. cosas como el color de las paredes, si tiene ventanas, cuantos enchufes tiene, etc. no son necesarias para este sistema

# %% [markdown]
# ## 2. Abstracción
#
# **Idea clave:** abstraer no es copiar toda la realidad, sino elegir las características relevantes para resolver un problema.
#
# Por ejemplo, una sala real puede tener muchos detalles:
# - color,
# - número de enchufes,
# - ventanas,
# - tipo de sillas,
# - proyector,
# - capacidad,
# - ubicación,
# - disponibilidad.
#
# Pero en esta primera versión del sistema, no todo eso es necesario.
#
# ### Actividad
# Escribe una breve reflexión:
#
# - ¿Qué atributos sí incluirías?
# - ¿Cuáles dejarías fuera?
# - ¿Por qué?

# %% [markdown]
# incluiria: nombre, capacidad, ubicacion y disponible. son los que realmente importan para saber si puedo usar la sala o no.
#
# dejaria fuera: color, enchufes, ventanas, tipo de sillas, proyector. esas cosas no afectan si la sala se puede reservar o no, asi que no tienen sentido incluirlas ahora.
#
# la idea es quedarse solo con lo necesario para que el sistema funcione, no modelar la sala completa.

# %% [markdown]
# ## 3. Conceptos iniciales
#
# ### Definiciones básicas
# - **Clase:** el molde o definición general.
# - **Objeto:** una instancia concreta creada a partir de una clase.
# - **Atributo:** una característica o dato del objeto.
# - **Método:** una acción o comportamiento del objeto.
# - **Interfaz (idea inicial):** el conjunto de acciones con las que se puede interactuar con el objeto.
#
# ### Preguntas de chequeo
# 1. ¿Cuál sería la clase principal en este problema?
# 2. ¿Qué objetos concretos podríamos crear?
# 3. ¿Qué serían atributos?
# 4. ¿Qué serían métodos?

# %%
respuesta_1 = "la clase principal seria Sala"
respuesta_2 = "por ejemplo: sala_a101, lab_info, auditorio"
respuesta_3 = "nombre, capacidad, ubicacion, disponible"
respuesta_4 = "mostrar_info, reservar, liberar"

print(respuesta_1)
print(respuesta_2)
print(respuesta_3)
print(respuesta_4)

# %% [markdown]
# ## 4. Primera estructura de una clase
#
# Observa esta estructura base:

# %%
class Sala:
    def __init__(self, nombre, capacidad, ubicacion, disponible=True):
        self.nombre = nombre
        self.capacidad = capacidad
        self.ubicacion = ubicacion
        self.disponible = disponible

# %% [markdown]
# ### Preguntas
# 1. ¿Qué representa la clase `Sala`?
# 2. ¿Qué hace `__init__`?
# 3. ¿Qué representan `self.nombre`, `self.capacidad`, etc.?
# 4. ¿Qué diferencia existe entre la clase y un objeto?

# %% [markdown]
# 1. la clase Sala representa el molde general de lo que es una sala, define que datos tiene y que puede hacer
#
# 2. el __init__ se ejecuta cuando se crea un objeto nuevo, sirve para asignarle los valores iniciales
#
# 3. son los atributos del objeto, cada sala tiene los suyos propios. el self hace referencia al objeto que se esta creando en ese momento
#
# 4. la clase es como el plano y el objeto es la sala concreta. por ejemplo Sala es el plano y sala_a101 es una sala real con nombre, capacidad, etc.

# %% [markdown]
# ## 5. Completa la clase
#
# Ahora agrega métodos simples a la clase.
#
# ### Tareas
# - Crear un método `mostrar_info()` que imprima la información principal de la sala.
# - Crear un método `reservar()` que deje la sala como no disponible si estaba libre.
# - Crear un método `liberar()` que deje la sala disponible nuevamente.
#
# ### Pista
# Recuerda que dentro de los métodos puedes acceder a los atributos usando `self`.

# %%
class Sala:
    def __init__(self, nombre, capacidad, ubicacion, disponible=True):
        self.nombre = nombre
        self.capacidad = capacidad
        self.ubicacion = ubicacion
        self.disponible = disponible

    def mostrar_info(self):
        print("Nombre:", self.nombre)
        print("Capacidad:", self.capacidad)
        print("Ubicacion:", self.ubicacion)
        print("Disponible:", self.disponible)

    def reservar(self):
        if self.disponible:
            self.disponible = False
            print("Sala reservada")
        else:
            print("La sala ya esta reservada")

    def liberar(self):
        self.disponible = True
        print("Sala liberada")

# %% [markdown]
# ## 6. Crear primeros objetos
#
# Una vez que completes la clase, crea al menos tres objetos distintos.
# Por ejemplo:
#
# - una sala de clases
# - un laboratorio
# - un auditorio
#
# Luego prueba sus métodos.

# %%
sala_a101 = Sala("A101", 35, "Edificio A")
lab_info = Sala("Lab Info 2", 25, "Edificio B")
auditorio = Sala("Auditorio Central", 120, "Edificio C")

# %% [markdown]
# ## 7. Pruebas
#
# Realiza pruebas simples:
# - mostrar información
# - reservar una sala
# - volver a mostrar información
# - liberar una sala
# - mostrar nuevamente
#
# ### Pregunta
# ¿Qué cambia en el estado del objeto cuando reservas o liberas una sala?

# %%
# pruebo con sala_a101
sala_a101.mostrar_info()
print()
sala_a101.reservar()
print()
sala_a101.mostrar_info()
print()
sala_a101.liberar()
print()
sala_a101.mostrar_info()

# %%
# pruebo con el lab
lab_info.mostrar_info()
print()
lab_info.reservar()
lab_info.reservar()  # intento reservar de nuevo para ver que pasa

# %% [markdown]
# cuando reservas la sala el atributo `disponible` cambia de True a False, y cuando la liberas vuelve a True. lo demas no cambia.

# %% [markdown]
# ## 8. Reflexión conceptual
#
# Responde brevemente:
#
# 1. ¿Qué diferencia hay entre la clase `Sala` y un objeto como `sala_a101`?
# 2. ¿Por qué la capacidad es un atributo y no un método?
# 3. ¿Por qué `reservar()` es un método y no un atributo?
# 4. ¿Qué entiendes por interfaz del objeto en esta actividad?

# %% [markdown]
# 1. la clase es el molde general y sala_a101 es un objeto concreto con valores reales. puedo crear muchos objetos distintos usando la misma clase
#
# 2. la capacidad es un dato que describe la sala, no es una accion que hace. por eso es atributo
#
# 3. reservar es algo que se hace, una accion que ademas cambia el estado del objeto. eso es un metodo
#
# 4. la interfaz seria el conjunto de metodos que puedo usar desde afuera para interactuar con la sala: mostrar_info, reservar y liberar. no necesito saber como funcionan por dentro, solo que hacen

# %% [markdown]
# ## 9. Desafío opcional
#
# Si terminas antes, intenta una o más de estas mejoras:
#
# - agregar el atributo `tipo_sala`
# - validar que la capacidad no sea negativa
# - mostrar la información en un formato más claro
# - crear una lista con varias salas y recorrerla para imprimir sus datos
# - impedir que una sala ya reservada se vuelva a reservar sin aviso

# %%
# agregue tipo_sala y valide que la capacidad no sea negativa

class Sala:
    def __init__(self, nombre, capacidad, ubicacion, tipo_sala="sala de clases", disponible=True):
        if capacidad < 0:
            print("Error: la capacidad no puede ser negativa")
            return
        self.nombre = nombre
        self.capacidad = capacidad
        self.ubicacion = ubicacion
        self.tipo_sala = tipo_sala
        self.disponible = disponible

    def mostrar_info(self):
        estado = "disponible" if self.disponible else "reservada"
        print(f"{self.nombre} | {self.tipo_sala} | cap: {self.capacidad} | {self.ubicacion} | {estado}")

    def reservar(self):
        if self.disponible:
            self.disponible = False
            print(f"{self.nombre} reservada")
        else:
            print(f"{self.nombre} ya esta reservada")

    def liberar(self):
        self.disponible = True
        print(f"{self.nombre} liberada")


# lista de salas
salas = [
    Sala("A101", 35, "Edificio A", "sala de clases"),
    Sala("Lab Info 2", 25, "Edificio B", "laboratorio"),
    Sala("Auditorio Central", 120, "Edificio C", "auditorio")
]

for s in salas:
    s.mostrar_info()

# %% [markdown]
# ## 10. Cierre
#
# La meta de este laboratorio no es aprender toda la Programación Orientada a Objetos en una sesión, sino comenzar a mirar un problema del mundo real y pensar cómo representarlo mediante objetos.
#
# ### Entrega
# - Notebook completo y ordenado.
# - Respuestas breves a las preguntas conceptuales.
# - Código funcional para la clase y los objetos creados.

# %% [markdown]
# me parecio util el laboratorio para entender como funciona esto de las clases y objetos. al principio no tenia claro la diferencia entre atributo y metodo pero con el ejemplo de la sala se entendio mejor. lo de la abstraccion tambien tiene sentido, no hay que modelar todo sino solo lo que sirve para el problema.
